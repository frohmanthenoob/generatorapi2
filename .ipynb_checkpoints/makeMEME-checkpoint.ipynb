# %%
from PIL import Image, ImageDraw, ImageFont

# %%
def meme(filename,fulltext,textsize=64,color=(255,255,255,255)): 
    image = Image.open('./img/'+filename+'.jpg')
    width, height = image.size
    print(width)
    print(height)
    draw = ImageDraw.Draw(image)
    text = fulltext
    font = ImageFont.truetype('./font/msjh.ttc', int(482))
    textwidth, textheight = draw.textsize(text, font)
    margin = 5
    x = (width - textwidth - margin)/2
    y = height - textheight - margin
    draw.text((x, y), text, font=font, fill=color)
    return image

# %%
meme("64","我")
# Out:
# 482
# 484
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=482x484 at 0x279B87B3390>
